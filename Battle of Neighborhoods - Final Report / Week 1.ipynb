# %% [markdown]
# # Coursera Capstone Project
#
# ## The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ###  Guillermo Del Castillo- Part 1 : Introduction and Data Sections

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Coursera Capstone - REPORT CONTENT
#
# 1.	Introduction Section :
# 	⁃	Discussion of the business problem and the interested audience in this project.
# 2.	Data Section:
# 	⁃	 Description of the data that will be used to solve the problem and the sources.
# 3.	Methodology section
# 	⁃	Discussion and description of exploratory data analysis carried out, any inferential statistical testing performed, and if any machine learnings were used establishing the strategy and purposes.
# 4.	Results section
# 	⁃	Discussion of the results.
# 5.	Discussion section
# 	⁃	Elaboration and discussion on any observations noted and any recommendations suggested based on the results.
# 6.	Conclusion section
# 	⁃	Report Conclusion.

# %%
# A description of the problem and a discussion of the background. (15 marks)

# %% [markdown]
# # 1.	Introduction Section :
# ### Discussion of the business problem and the audience who would be interested in this project.

# %% [markdown]
# ### Description of the Problem and Background
#
# ### Scenario:
#
# I am a data scientist residing in Downtown Singapore.
# I currently live within walking distance to Downtown Telok Ayer MRT metro station and I enjoy many ammenities and venues in the area, such as various international cousine restaurants, cafes, food shops and entertainment.
# I have been offered a great opportunity to work for a leader firm in Manhattan, NY. I am very excited and I want to use this opportunity to practice my learnings in Coursera in order to answer relevant questions arisen.
# The key question is :  How can I find a convenient and enjoyable place similar to mine now in Singapore?
# Certainly, I can use available real estate apps and Google but the idea is to use and apply myself the learned tools during the course.
# In order to make a comparison and evaluation of the rental options in Manhattan NY, I must set some basis, therefore the apartment in Manhattan must meet the following demands:
#  - apartment must be 2 or 3 bedrooms
#  - desired location is near a metro station in the Manhattan area and within 1.0 mile (1.6 km) radius
#  - price of rent not exceed $7,000 per month
#  - top ammenities in the selected neighborhood shall be similar to current residence
#  - desirable to have venues such as coffee shops, restaurants Asian Thai, wine stores, gym and food shops
#  - as a reference, I have included a map of venues near current residence in Singapore.

# %% [markdown]
# ### Business Problem:
# The challenge is to find a suitable apartment for rent in Manhattan NY that complies with the demands on location, price and venues. The data required to resolve this challenge is described in the following section 2, below.
#
#
# ### Interested Audience
# I believe this is a relevant challenge with valid questions for anyone moving to other large city in US, EU or Asia. The same methodology can be applied in accordance to demands as applicable. This case is also applicable for anyone interested in exploring starting or locating a new business in any city. Lastly, it can also serve as a good practical exercise to develop Data Science skills.

# %%
# A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# # 2. Data Section:¶
# ### Description of the data and its sources that will be used to solve the problem

# %% [markdown]
# ### Description of the Data:¶
#
# The following data is required to  answer the issues of the problem:
#
# - List of Boroughs and neighborhoods of Manhattan with their geodata (latitud and longitud)
# - List of Subway metro stations in Manhattan with their address location
# - List of apartments for rent in Manhattan area with their addresses and price
# - Preferably, a list of apartment for rent with additional information, such as price, address, area, # of beds, etc
# - Venues for each Manhattan neighborhood ( than can be clustered)
# - Venues for subway metro stations, as needed
#
#
# ### How the data will be used to solve the problem
#
# The data will be used as follows:
# - Use Foursquare and geopy data to map top 10 venues for all Manhattan neighborhoods and clustered in groups ( as per Course LAB)
# - Use foursquare and geopy data to map the location of subway metro stations , separately and on top of the above clustered map in order to be able to identify the venues and ammenities near each metro station, or explore each subway location separately
# - Use Foursquare and geopy data to map the location of rental places, in some form, linked to the subway locations.
# - create a map that depicts, for instance, the average rental price per square ft, around a radious of 1.0 mile (1.6 km) around each subway station - or a similar metrics. I will be able to quickly point to the popups to know the relative price per subway area.
# - Addresses from rental locations will be converted to geodata( lat, long) using Geopy-distance and Nominatim.
# - Data will be searched in open data sources if available, from real estate sites if open to reading, libraries or other government agencies such as Metro New York MTA, etc.
#
#
# The procesing of these DATA will allow to answer the key questions to make a decision:
# - what is the cost of rent (per square ft) around a mile radius from each subway metro station?
# - what is the area of Manhattan with best rental pricing that meets criteria established?
# - What is the distance from work place ( Park Ave and 53 rd St) and the tentative future home?
# - What are the venues of the two best places to live? How the prices compare?
# - How venues distribute among Manhattan neighborhoods and around metro stations?
# - Are there tradeoffs between size and price and location?
# - Any other interesting statistical data findings of the real estate and overall data.

# %% [markdown]
# ### Reference of venues around current residence in Quito, Ecuador for comparison to Manhattan place

# %%
address = 'Quito, Ecuador'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Quito home are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# The geograpical coordinate of Quito home are -0.2201641, -78.5123274.

# %%
neighborhood_latitude=-0.2201641
neighborhood_longitude=-78.5123274

# %%
# The code was removed by Watson Studio for sharing.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=E2DPU0TK2QPK54OMTSAYVQXEIWZBXKKC31GCMACS53PL03UF&client_secret=CEXLZYR2GTBRT1DME2STYLMETRBHPMGMUJNQEXUXJUWICF4X&v=20180605&ll=-0.2201641,-78.5123274&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f1637ae9cc8a848566c2efd'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Centro Histórico',
#   'headerFullLocation': 'Centro Histórico, Quito',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 59,
#   'suggestedBounds': {'ne': {'lat': -0.2156640954999955,
#     'lng': -78.50783576436277},
#    'sw': {'lat': -0.2246641045000045, 'lng': -78.51681903563724}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3b359d483b04e17a78b467',
#        'name': 'Centro Cultural Metropolitano',
#        'location': {'address': 'Garcia Moreno',
#         'crossStreet': 'Espejo',
#         'lat': -0.2201584571344043,
#         'lng': -78.51309136971402,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2201584571344043,
#           'lng': -78.51309136971402}],
#         'distance': 85,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Garcia Moreno (Espejo)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e3b359d483b04e17a78b467-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8e7ed9d4ec8cfa6e797589',
#        'name': 'La Compañía de Jesus',
#        'location': {'address': 'Garcia Moreno',
#         'crossStreet': 'Cuenca',
#         'lat': -0.22110751205022997,
#         'lng': -78.51359326445397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22110751205022997,
#           'lng': -78.51359326445397}],
#         'distance': 175,
#         'postalCode': '170401',
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Garcia Moreno (Cuenca)',
#          '170401',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8e7ed9d4ec8cfa6e797589-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e066f9ad22d658532a010f2',
#        'name': 'Catedral Metropolitana',
#        'location': {'address': 'Venezuela y Espejo',
#         'lat': -0.2202387931872399,
#         'lng': -78.51234147285778,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2202387931872399,
#           'lng': -78.51234147285778}],
#         'distance': 8,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Venezuela y Espejo', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e066f9ad22d658532a010f2-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7da24df964a52039cb2fe3',
#        'name': 'Plaza Grande',
#        'location': {'address': 'Chile y',
#         'crossStreet': 'Benalcazar',
#         'lat': -0.22032683431001598,
#         'lng': -78.51216316223145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22032683431001598,
#           'lng': -78.51216316223145}],
#         'distance': 25,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Chile y (Benalcazar)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7da24df964a52039cb2fe3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5dee5929ef236a2ac08659',
#        'name': 'Hotel Plaza Grande',
#        'location': {'address': 'Garcia Moreno',
#         'crossStreet': 'Chile',
#         'lat': -0.21958969283076382,
#         'lng': -78.51209102884555,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21958969283076382,
#           'lng': -78.51209102884555}],
#         'distance': 69,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Garcia Moreno (Chile)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5dee5929ef236a2ac08659-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb43fc8be7bfc2849c90105',
#        'name': 'Café Plaza Grande',
#        'location': {'address': 'García Moreno y Chile',
#         'lat': -0.21972280695884072,
#         'lng': -78.51222734199828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21972280695884072,
#           'lng': -78.51222734199828}],
#         'distance': 50,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['García Moreno y Chile', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb43fc8be7bfc2849c90105-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdeef2041ed224b632ddc3c',
#        'name': 'Palacio Arzobispal',
#        'location': {'address': 'Chile',
#         'crossStreet': 'Venezuela',
#         'lat': -0.21949137746569797,
#         'lng': -78.51168508254801,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21949137746569797,
#           'lng': -78.51168508254801}],
#         'distance': 103,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Chile (Venezuela)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdeef2041ed224b632ddc3c-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f13163ee4b019e992d5b16d',
#        'name': 'Museo de Cera Alberto Mena Caamaño',
#        'location': {'address': 'Espejo',
#         'crossStreet': 'Garcia Moreno',
#         'lat': -0.21984276357914226,
#         'lng': -78.51299556728797,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21984276357914226,
#           'lng': -78.51299556728797}],
#         'distance': 82,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Espejo (Garcia Moreno)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f13163ee4b019e992d5b16d-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bba1a9a3db7b713cbe5229a',
#        'name': 'Plaza San Francisco',
#        'location': {'lat': -0.2207521175517749,
#         'lng': -78.5148742376705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2207521175517749,
#           'lng': -78.5148742376705}],
#         'distance': 290,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bba1a9a3db7b713cbe5229a-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e79f23f8998c6d2894aea9a',
#        'name': 'Dulceria Colonial',
#        'location': {'lat': -0.22038465896345313,
#         'lng': -78.51203707304309,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22038465896345313,
#           'lng': -78.51203707304309}],
#         'distance': 40,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e79f23f8998c6d2894aea9a-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3b863044f5a0931a73c4bb',
#        'name': 'Vista hermosa',
#        'location': {'address': 'Mejia 453',
#         'crossStreet': 'Gabriel García Moreno',
#         'lat': -0.2192138597850573,
#         'lng': -78.51140836212481,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2192138597850573,
#           'lng': -78.51140836212481}],
#         'distance': 147,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Mejia 453 (Gabriel García Moreno)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3b863044f5a0931a73c4bb-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53cbeea6498edc8c0e58bbae',
#        'name': 'En Dulce',
#        'location': {'lat': -0.21951219302791697,
#         'lng': -78.509917714504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21951219302791697,
#           'lng': -78.509917714504}],
#         'distance': 277,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53cbeea6498edc8c0e58bbae-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '521b5fbe11d27d4e2e7919ea',
#        'name': 'Los Sanduches De La Plaza Grande',
#        'location': {'lat': -0.21992654517733726,
#         'lng': -78.51172083648554,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21992654517733726,
#           'lng': -78.51172083648554}],
#         'distance': 72,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-521b5fbe11d27d4e2e7919ea-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '504cb06be4b03c3db1d5bf3b',
#        'name': 'Centro Comercial Palacio Arzobispal',
#        'location': {'address': 'Venezuela',
#         'crossStreet': 'García Moreno',
#         'lat': -0.21943368370679261,
#         'lng': -78.51163609493081,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21943368370679261,
#           'lng': -78.51163609493081}],
#         'distance': 111,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Venezuela (García Moreno)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-504cb06be4b03c3db1d5bf3b-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5637bac4498efb578d417520',
#        'name': 'Cafeteria Fabiolita',
#        'location': {'lat': -0.220464,
#         'lng': -78.512129,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.220464,
#           'lng': -78.512129}],
#         'distance': 40,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1cd941735',
#          'name': 'South American Restaurant',
#          'pluralName': 'South American Restaurants',
#          'shortName': 'South American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5637bac4498efb578d417520-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '579d3029498e38b4e6681ae5',
#        'name': 'La Purísima',
#        'location': {'address': 'Espejo en los bajos del Teatro Bolívar',
#         'crossStreet': 'Guayaquil',
#         'lat': -0.221355,
#         'lng': -78.511079,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.221355,
#           'lng': -78.511079}],
#         'distance': 192,
#         'cc': 'EC',
#         'city': 'Centro Histórico',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Espejo en los bajos del Teatro Bolívar (Guayaquil)',
#          'Quito- Centro Histórico',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-579d3029498e38b4e6681ae5-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb6e1c77ee5024d7fa1a2d5',
#        'name': 'Casa Gangotena',
#        'location': {'lat': -0.22124227644449548,
#         'lng': -78.51544183792397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22124227644449548,
#           'lng': -78.51544183792397}],
#         'distance': 366,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb6e1c77ee5024d7fa1a2d5-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e066ebbb0fbba5eee160a91',
#        'name': 'Iglesia De Santo domingo',
#        'location': {'lat': -0.22341648078499665,
#         'lng': -78.5128671702356,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22341648078499665,
#           'lng': -78.5128671702356}],
#         'distance': 367,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e066ebbb0fbba5eee160a91-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '531a15d7498eaf05eb1a2741',
#        'name': 'Plaza Chica Cafe',
#        'location': {'address': 'Calle Venezuela y Chile. Plaza Carlos Andrade Marin (Dentro del Palacio Municipal)',
#         'crossStreet': 'Dentro del Palacio Municipal',
#         'lat': -0.22059505322596998,
#         'lng': -78.51115196943282,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22059505322596998,
#           'lng': -78.51115196943282}],
#         'distance': 139,
#         'postalCode': '170130',
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Calle Venezuela y Chile. Plaza Carlos Andrade Marin (Dentro del Palacio Municipal) (Dentro del Palacio Municipal)',
#          '170130',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d128941735',
#          'name': 'Cafeteria',
#          'pluralName': 'Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '88602689'}},
#       'referralId': 'e-0-531a15d7498eaf05eb1a2741-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1de93e14955b99c41b61b3',
#        'name': 'San Agustín Heladería',
#        'location': {'address': 'Guayaquil',
#         'crossStreet': 'Mejia',
#         'lat': -0.2201024071892292,
#         'lng': -78.51043622680925,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2201024071892292,
#           'lng': -78.51043622680925}],
#         'distance': 210,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Guayaquil (Mejia)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1de93e14955b99c41b61b3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55c3eeee498eeeeaaadae04d',
#        'name': 'Galletti coffee roasters',
#        'location': {'address': 'Venezuela',
#         'crossStreet': 'Espejo',
#         'lat': -0.2213361599669393,
#         'lng': -78.51107628522261,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2213361599669393,
#           'lng': -78.51107628522261}],
#         'distance': 190,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Venezuela (Espejo)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55c3eeee498eeeeaaadae04d-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dda84b67d8b322664380e99',
#        'name': 'Cafeteria Restaurant Meneses e Hijos',
#        'location': {'address': 'Chile',
#         'lat': -0.22083666997697698,
#         'lng': -78.51022840857291,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22083666997697698,
#           'lng': -78.51022840857291}],
#         'distance': 245,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Chile', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dda84b67d8b322664380e99-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b86ea83f964a520bba531e3',
#        'name': 'Teatro Sucre',
#        'location': {'address': 'Manabí N8-131',
#         'crossStreet': 'Guayaquil',
#         'lat': -0.21878179312099144,
#         'lng': -78.5087099040194,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21878179312099144,
#           'lng': -78.5087099040194}],
#         'distance': 431,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Manabí N8-131 (Guayaquil)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b86ea83f964a520bba531e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50635c0a498ed60c6e51b56e',
#        'name': 'Juan Fogonero',
#        'location': {'lat': -0.21937433184337873,
#         'lng': -78.5115543957968,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21937433184337873,
#           'lng': -78.5115543957968}],
#         'distance': 123,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50635c0a498ed60c6e51b56e-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e063c16b0fbba5eee1488be',
#        'name': 'Iglesia de San francisco (Iglesia de San Francisco)',
#        'location': {'lat': -0.2190024228391698,
#         'lng': -78.51589840846357,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2190024228391698,
#           'lng': -78.51589840846357}],
#         'distance': 418,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e063c16b0fbba5eee1488be-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8ebd121716a143c8f23af7',
#        'name': 'Cafeteria Modelo',
#        'location': {'address': 'Venezuela',
#         'crossStreet': 'Sucre',
#         'lat': -0.22130293245487506,
#         'lng': -78.513626562913,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22130293245487506,
#           'lng': -78.513626562913}],
#         'distance': 192,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Venezuela (Sucre)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8ebd121716a143c8f23af7-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee01829be7b7e4d122c9b6f',
#        'name': 'Dios No Muere',
#        'location': {'address': 'N4-10',
#         'crossStreet': 'Juan José Flores/Junín',
#         'lat': -0.22217929223691038,
#         'lng': -78.51089972644273,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22217929223691038,
#           'lng': -78.51089972644273}],
#         'distance': 274,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['N4-10 (Juan José Flores/Junín)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee01829be7b7e4d122c9b6f-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55c8d6ce498e0dc257f30a78',
#        'name': "San Mateo's",
#        'location': {'address': 'Plaza De Las Conceptas',
#         'crossStreet': 'Garcia Moreno',
#         'lat': -0.218849293219184,
#         'lng': -78.51165980826464,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.218849293219184,
#           'lng': -78.51165980826464}],
#         'distance': 164,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Plaza De Las Conceptas (Garcia Moreno)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55c8d6ce498e0dc257f30a78-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c0c8aee4b00a170e049c36',
#        'name': 'Museo de la Ciudad',
#        'location': {'address': 'Quito',
#         'lat': -0.22335398999053974,
#         'lng': -78.51499966246239,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22335398999053974,
#           'lng': -78.51499966246239}],
#         'distance': 463,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c0c8aee4b00a170e049c36-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '598b840616ef6706694fe971',
#        'name': 'Hasta la vuelta Señor',
#        'location': {'address': 'Centro Comercial Pasaje Arzobispal, Patio de Comidas 3 Piso',
#         'lat': -0.219743,
#         'lng': -78.511768,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.219743,
#           'lng': -78.511768}],
#         'distance': 77,
#         'postalCode': '170401',
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Centro Comercial Pasaje Arzobispal, Patio de Comidas 3 Piso',
#          '170401',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-598b840616ef6706694fe971-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50b16e8de4b053168a4cc52d',
#        'name': 'Republica del Cacao',
#        'location': {'lat': -0.219867,
#         'lng': -78.511228,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.219867,
#           'lng': -78.511228}],
#         'distance': 126,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50b16e8de4b053168a4cc52d-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d24b71053e4a09334ca8977',
#        'name': 'Pizza SA',
#        'location': {'address': 'Guayaquil',
#         'crossStreet': 'Bolivar',
#         'lat': -0.22134403324094898,
#         'lng': -78.51106052766268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22134403324094898,
#           'lng': -78.51106052766268}],
#         'distance': 192,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Guayaquil (Bolivar)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d24b71053e4a09334ca8977-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e46d49db61c03d0cd1191cc',
#        'name': 'Museo Casa del Alabado',
#        'location': {'address': 'Calle Cuenca N1-41',
#         'crossStreet': 'Entre la plazas de San Francisco y Santa Clara',
#         'lat': -0.22142892443543843,
#         'lng': -78.51589876636638,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22142892443543843,
#           'lng': -78.51589876636638}],
#         'distance': 421,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Calle Cuenca N1-41 (Entre la plazas de San Francisco y Santa Clara)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '76336806'}},
#       'referralId': 'e-0-4e46d49db61c03d0cd1191cc-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbb3f75c7228cfaea801cce',
#        'name': 'La Colmena',
#        'location': {'address': 'Sebastián de Benalcazar N31-19',
#         'crossStreet': 'Espejo',
#         'lat': -0.21975893857536463,
#         'lng': -78.5135577340882,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21975893857536463,
#           'lng': -78.5135577340882}],
#         'distance': 144,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Sebastián de Benalcazar N31-19 (Espejo)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d17a941735',
#          'name': 'Cajun / Creole Restaurant',
#          'pluralName': 'Cajun / Creole Restaurants',
#          'shortName': 'Cajun / Creole',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cbb3f75c7228cfaea801cce-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee2564361aff90fe4779e1c',
#        'name': 'Patio Andaluz',
#        'location': {'lat': -0.2187026707744944,
#         'lng': -78.51103125242113,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2187026707744944,
#           'lng': -78.51103125242113}],
#         'distance': 217,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee2564361aff90fe4779e1c-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ff2acae4b09ecf5e5918d8',
#        'name': 'Govinda Restaurante Vegetariano',
#        'location': {'address': 'Esmeraldas',
#         'crossStreet': 'Venezuela',
#         'lat': -0.217862,
#         'lng': -78.50925,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.217862,
#           'lng': -78.50925}],
#         'distance': 427,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Esmeraldas (Venezuela)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50ff2acae4b09ecf5e5918d8-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '505fb306e4b05a5f273960bb',
#        'name': 'Hotel Boutique Portal De Cantuña',
#        'location': {'address': 'Bolivar OE 6-105 y Cuenca',
#         'lat': -0.22098945053643707,
#         'lng': -78.51596319227396,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22098945053643707,
#           'lng': -78.51596319227396}],
#         'distance': 415,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'P',
#         'country': 'Ecuador',
#         'formattedAddress': ['Bolivar OE 6-105 y Cuenca', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-505fb306e4b05a5f273960bb-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6598cfc2ead13aa46eb180',
#        'name': 'Café del Fraile',
#        'location': {'address': 'García Moreno',
#         'crossStreet': 'Chile',
#         'lat': -0.21945690986456856,
#         'lng': -78.51164404564553,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21945690986456856,
#           'lng': -78.51164404564553}],
#         'distance': 109,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['García Moreno (Chile)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c6598cfc2ead13aa46eb180-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec311d961affbd6905cd65a',
#        'name': 'Hotel Real Audiencia',
#        'location': {'address': 'Guayaquil, Quito',
#         'lat': -0.22296404900264485,
#         'lng': -78.51291708307267,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22296404900264485,
#           'lng': -78.51291708307267}],
#         'distance': 318,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Guayaquil, Quito', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec311d961affbd6905cd65a-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5297b84a498e540e49cd2efe',
#        'name': 'La Primera Casa',
#        'location': {'lat': -0.22393714201313797,
#         'lng': -78.5146834351263,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22393714201313797,
#           'lng': -78.5146834351263}],
#         'distance': 495,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5297b84a498e540e49cd2efe-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de8d8c4fa76fd1168aa0378',
#        'name': 'Plaza Del Teatro',
#        'location': {'address': 'Calle Guayaquil',
#         'crossStreet': 'Calle Mejia',
#         'lat': -0.21894113614982824,
#         'lng': -78.50844190470671,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21894113614982824,
#           'lng': -78.50844190470671}],
#         'distance': 453,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Calle Guayaquil (Calle Mejia)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de8d8c4fa76fd1168aa0378-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb455977ee5024d7e8a9a2c',
#        'name': 'Heladeria & Café Caribe',
#        'location': {'address': 'Bolivar y Venezuela',
#         'lat': -0.22255395533828304,
#         'lng': -78.51352164201626,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22255395533828304,
#           'lng': -78.51352164201626}],
#         'distance': 297,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Bolivar y Venezuela', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
# ...
#           'lng': -78.51253945880134}],
#         'distance': 248,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec74f8b30f8b09c0bcbb4a3-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f369d42e4b0d408a38b46d4',
#        'name': 'Centro Comercial La Merced',
#        'location': {'address': 'Vicente Rocafuerte',
#         'crossStreet': 'Chile',
#         'lat': -0.217438,
#         'lng': -78.514703,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.217438,
#           'lng': -78.514703}],
#         'distance': 402,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Vicente Rocafuerte (Chile)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f369d42e4b0d408a38b46d4-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51ef3f90498e1fe7165bba49',
#        'name': 'Pondo de barro',
#        'location': {'lat': -0.224029,
#         'lng': -78.51428,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.224029,
#           'lng': -78.51428}],
#         'distance': 482,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1cd941735',
#          'name': 'South American Restaurant',
#          'pluralName': 'South American Restaurants',
#          'shortName': 'South American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51ef3f90498e1fe7165bba49-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec28f5d4901f56b0f3c0e0b',
#        'name': 'San Ignacio Restaurant',
#        'location': {'address': 'Garcia Moreno N2-60',
#         'crossStreet': 'Sucre',
#         'lat': -0.22138917300933367,
#         'lng': -78.5138623490159,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22138917300933367,
#           'lng': -78.5138623490159}],
#         'distance': 218,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Garcia Moreno N2-60 (Sucre)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec28f5d4901f56b0f3c0e0b-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '502ff17de4b0beacbe73df05',
#        'name': 'Museo Numismatico',
#        'location': {'lat': -0.22098703566561143,
#         'lng': -78.51332974908766,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22098703566561143,
#           'lng': -78.51332974908766}],
#         'distance': 144,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-502ff17de4b0beacbe73df05-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e24acff814d32181a6f546d',
#        'name': 'Belle Epoque',
#        'location': {'address': 'García Moreno',
#         'crossStreet': 'Chile',
#         'lat': -0.21967238013487003,
#         'lng': -78.51204514503479,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21967238013487003,
#           'lng': -78.51204514503479}],
#         'distance': 63,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['García Moreno (Chile)', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e24acff814d32181a6f546d-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d94080845ae5481a920fceb',
#        'name': 'Hotel Boutique Plaza Sucre',
#        'location': {'address': 'Sucre Oe2-36 entre Guayaquil y Flores',
#         'lat': -0.22260845088799455,
#         'lng': -78.51202528587913,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22260845088799455,
#           'lng': -78.51202528587913}],
#         'distance': 274,
#         'postalCode': '170401',
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Sucre Oe2-36 entre Guayaquil y Flores',
#          '170401',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d94080845ae5481a920fceb-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e0404cc814d2440c200d535',
#        'name': 'Fybeca',
#        'location': {'address': 'Guayaquil N9 01 y Esmeraldas (esquina)',
#         'lat': -0.2185421850172141,
#         'lng': -78.5082095861435,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2185421850172141,
#           'lng': -78.5082095861435}],
#         'distance': 492,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Guayaquil N9 01 y Esmeraldas (esquina)',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e0404cc814d2440c200d535-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e91ecf029c2117fa4604906',
#        'name': 'Leña Quiteña',
#        'location': {'address': 'Paredes',
#         'crossStreet': 'Piedra',
#         'lat': -0.2243584938056011,
#         'lng': -78.51386789692702,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2243584938056011,
#           'lng': -78.51386789692702}],
#         'distance': 497,
#         'cc': 'EC',
#         'city': 'Quito DC',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Paredes (Piedra)', 'Quito DC', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e91ecf029c2117fa4604906-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5160d23be4b0b5e5f67b4ce6',
#        'name': 'Leña Quiteña',
#        'location': {'lat': -0.22428664996528125,
#         'lng': -78.5139400196167,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.22428664996528125,
#           'lng': -78.5139400196167}],
#         'distance': 492,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5160d23be4b0b5e5f67b4ce6-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eaa00bb9adfbd5e5ceee2f8',
#        'name': 'Teatro Variedades Ernesto Alban',
#        'location': {'lat': -0.21888692945450847,
#         'lng': -78.5083642299133,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21888692945450847,
#           'lng': -78.5083642299133}],
#         'distance': 463,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eaa00bb9adfbd5e5ceee2f8-54'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4deaea207d8b6c7a534d3c7e',
#        'name': 'Theatrum Restaurante & Wine Bar',
#        'location': {'address': 'Av. Guayaquil',
#         'lat': -0.21887781758510516,
#         'lng': -78.50873136712335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21887781758510516,
#           'lng': -78.50873136712335}],
#         'distance': 425,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Av. Guayaquil', 'Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4deaea207d8b6c7a534d3c7e-55'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4efccc8ef9ab0847fa635c96',
#        'name': 'El Relicario Del Carmen',
#        'location': {'lat': -0.2188845654287572,
#         'lng': -78.51084424579514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.2188845654287572,
#           'lng': -78.51084424579514}],
#         'distance': 218,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4efccc8ef9ab0847fa635c96-56'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5863e1b545005e7adce5141d',
#        'name': 'Mercado Ipiales',
#        'location': {'lat': -0.21838862,
#         'lng': -78.51527,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.21838862,
#           'lng': -78.51527}],
#         'distance': 382,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Quito', 'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1f7941735',
#          'name': 'Flea Market',
#          'pluralName': 'Flea Markets',
#          'shortName': 'Flea Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5863e1b545005e7adce5141d-57'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ad0c404f1936e63e73a1157',
#        'name': 'Masaya Quito',
#        'location': {'address': 'Calle Rocafuerte OE3 – 85 y Venezuela',
#         'lat': -0.223392,
#         'lng': -78.514102,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -0.223392,
#           'lng': -78.514102}],
#         'distance': 410,
#         'cc': 'EC',
#         'city': 'Quito',
#         'state': 'Pichincha',
#         'country': 'Ecuador',
#         'formattedAddress': ['Calle Rocafuerte OE3 – 85 y Venezuela',
#          'Quito',
#          'Ecuador']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ad0c404f1936e63e73a1157-58'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
SGnearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]

# filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)

# clean columns
SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.head(10)
# Out:
#                                  name      categories       lat        lng
# 0       Centro Cultural Metropolitano     Art Gallery -0.220158 -78.513091
# 1                La Compañía de Jesus          Church -0.221108 -78.513593
# 2              Catedral Metropolitana   Historic Site -0.220239 -78.512341
# 3                        Plaza Grande           Plaza -0.220327 -78.512163
# 4                  Hotel Plaza Grande           Hotel -0.219590 -78.512091
# 5                   Café Plaza Grande  Breakfast Spot -0.219723 -78.512227
# 6                  Palacio Arzobispal   Historic Site -0.219491 -78.511685
# 7  Museo de Cera Alberto Mena Caamaño  History Museum -0.219843 -78.512996
# 8                 Plaza San Francisco           Plaza -0.220752 -78.514874
# 9                   Dulceria Colonial     Coffee Shop -0.220385 -78.512037

# %% [markdown]
# ## Map of Quito-Ecuador with venues near residence place - for reference

# %%
# create map of Singapore place  using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=20)

# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=4,
        radius=10,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.7,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Thanks !!

# %%
## 3.	Methodology section

# %%
## 4.	Results section

# %%
## 5.	Discussion section

# %%
## 6.	Conclusion section
